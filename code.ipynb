# %%
import pandas as pd

# %%
dataset = pd.read_csv('energy_consumption_prediction_dataset.csv')
pd.set_option('display.max_columns', None)
dataset
# Out:
#       Operation_Date  Year  Month  Quarter Day_of_Week Weekend Peak_Season  \
# 0         2022-01-01  2022      1        1    Saturday     Yes          No
# 1         2022-01-01  2022      1        1    Saturday     Yes          No
# 2         2022-01-01  2022      1        1    Saturday     Yes          No
# 3         2022-01-01  2022      1        1    Saturday     Yes          No
# 4         2022-01-01  2022      1        1    Saturday     Yes          No
# ...              ...   ...    ...      ...         ...     ...         ...
# 17527     2025-12-31  2025     12        4   Wednesday      No         Yes
# 17528     2025-12-31  2025     12        4   Wednesday      No         Yes
# 17529     2025-12-31  2025     12        4   Wednesday      No         Yes
# 17530     2025-12-31  2025     12        4   Wednesday      No         Yes
# 17531     2025-12-31  2025     12        4   Wednesday      No         Yes
#
# ...
